# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydicom
#   Downloading pydicom-2.3.1-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 12.7 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.3.1

# %%
import numpy as np
import pandas as pd
import pydicom
import os
import random
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow.keras.layers as L
import tensorflow.keras.models as M

# %%
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import plotly.express as px
import plotly.graph_objects as go

# %%
random.seed(42)
os.environ['PYTHONHASHSEED'] = str(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
path="/content/drive/My Drive/FYP/GRU/"

# %%
BATCH_SIZE= 128

# %% [markdown]
# DROPING DUPLICATES

# %%
train = pd.read_csv(path+"train.csv")
print("before droping duplicates:",len(train))
train.drop_duplicates(keep=False, inplace=True, subset=['Patient','Weeks'])
print("after droping duplicates:",len(train))
test = pd.read_csv(path+"test.csv")
# Out:
# before droping duplicates: 1549
# after droping duplicates: 1535

# %%
test
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00419637202311204720264      6  3020  70.186855   73  Male     Ex-smoker
# 1  ID00421637202311550012437     15  2739  82.045291   68  Male     Ex-smoker
# 2  ID00422637202311677017371      6  1930  76.672493   73  Male     Ex-smoker
# 3  ID00423637202312137826377     17  3294  79.258903   72  Male     Ex-smoker
# 4  ID00426637202313170790466      0  2925  71.824968   73  Male  Never smoked

# %%
sub = pd.read_csv(path+"sample_submission.csv")
sub
# Out:
#                       Patient_Week   FVC  Confidence
# 0    ID00419637202311204720264_-12  2000         100
# 1    ID00421637202311550012437_-12  2000         100
# 2    ID00422637202311677017371_-12  2000         100
# 3    ID00423637202312137826377_-12  2000         100
# 4    ID00426637202313170790466_-12  2000         100
# ..                             ...   ...         ...
# 725  ID00419637202311204720264_133  2000         100
# 726  ID00421637202311550012437_133  2000         100
# 727  ID00422637202311677017371_133  2000         100
# 728  ID00423637202312137826377_133  2000         100
# 729  ID00426637202313170790466_133  2000         100
#
# [730 rows x 3 columns]

# %% [markdown]
# Splitting "Patient_Week" column as "Patient" and "Week"

# %%
sub = pd.read_csv(path+"sample_submission.csv")
sub['Patient'] = sub['Patient_Week'].apply(lambda x:x.split('_')[0])
sub['Weeks'] = sub['Patient_Week'].apply(lambda x: int(x.split('_')[-1]))
sub =  sub[['Patient','Weeks','Confidence','Patient_Week']]
sub
# Out:
#                        Patient  Weeks  Confidence  \
# 0    ID00419637202311204720264    -12         100
# 1    ID00421637202311550012437    -12         100
# 2    ID00422637202311677017371    -12         100
# 3    ID00423637202312137826377    -12         100
# 4    ID00426637202313170790466    -12         100
# ..                         ...    ...         ...
# 725  ID00419637202311204720264    133         100
# 726  ID00421637202311550012437    133         100
# 727  ID00422637202311677017371    133         100
# 728  ID00423637202312137826377    133         100
# 729  ID00426637202313170790466    133         100
#
#                       Patient_Week
# 0    ID00419637202311204720264_-12
# 1    ID00421637202311550012437_-12
# 2    ID00422637202311677017371_-12
# 3    ID00423637202312137826377_-12
# 4    ID00426637202313170790466_-12
# ..                             ...
# 725  ID00419637202311204720264_133
# 726  ID00421637202311550012437_133
# 727  ID00422637202311677017371_133
# 728  ID00423637202312137826377_133
# 729  ID00426637202313170790466_133
#
# [730 rows x 4 columns]

# %%
sub['Weeks']
# Out:
# 0      -12
# 1      -12
# 2      -12
# 3      -12
# 4      -12
#       ...
# 725    133
# 726    133
# 727    133
# 728    133
# 729    133
# Name: Weeks, Length: 730, dtype: int64

# %%
sub = sub.merge(test.drop('Weeks', axis=1), on="Patient")
sub
# Out:
#                        Patient  Weeks  Confidence  \
# 0    ID00419637202311204720264    -12         100
# 1    ID00419637202311204720264    -11         100
# 2    ID00419637202311204720264    -10         100
# 3    ID00419637202311204720264     -9         100
# 4    ID00419637202311204720264     -8         100
# ..                         ...    ...         ...
# 725  ID00426637202313170790466    129         100
# 726  ID00426637202313170790466    130         100
# 727  ID00426637202313170790466    131         100
# 728  ID00426637202313170790466    132         100
# 729  ID00426637202313170790466    133         100
#
#                       Patient_Week   FVC    Percent  Age   Sex SmokingStatus
# 0    ID00419637202311204720264_-12  3020  70.186855   73  Male     Ex-smoker
# 1    ID00419637202311204720264_-11  3020  70.186855   73  Male     Ex-smoker
# 2    ID00419637202311204720264_-10  3020  70.186855   73  Male     Ex-smoker
# 3     ID00419637202311204720264_-9  3020  70.186855   73  Male     Ex-smoker
# 4     ID00419637202311204720264_-8  3020  70.186855   73  Male     Ex-smoker
# ..                             ...   ...        ...  ...   ...           ...
# 725  ID00426637202313170790466_129  2925  71.824968   73  Male  Never smoked
# 726  ID00426637202313170790466_130  2925  71.824968   73  Male  Never smoked
# 727  ID00426637202313170790466_131  2925  71.824968   73  Male  Never smoked
# 728  ID00426637202313170790466_132  2925  71.824968   73  Male  Never smoked
# 729  ID00426637202313170790466_133  2925  71.824968   73  Male  Never smoked
#
# [730 rows x 9 columns]

# %%
train.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00007637202177411956430     -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430      5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430      7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430      9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430     11  2069  52.063412   79  Male     Ex-smoker

# %%
test.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00419637202311204720264      6  3020  70.186855   73  Male     Ex-smoker
# 1  ID00421637202311550012437     15  2739  82.045291   68  Male     Ex-smoker
# 2  ID00422637202311677017371      6  1930  76.672493   73  Male     Ex-smoker
# 3  ID00423637202312137826377     17  3294  79.258903   72  Male     Ex-smoker
# 4  ID00426637202313170790466      0  2925  71.824968   73  Male  Never smoked

# %%
train['WHERE'] = 'train'
test['WHERE'] = 'val'
sub['WHERE'] = 'test'

# %%
train
# Out:
#                         Patient  Weeks   FVC    Percent  Age   Sex  \
# 0     ID00007637202177411956430     -4  2315  58.253649   79  Male
# 1     ID00007637202177411956430      5  2214  55.712129   79  Male
# 2     ID00007637202177411956430      7  2061  51.862104   79  Male
# 3     ID00007637202177411956430      9  2144  53.950679   79  Male
# 4     ID00007637202177411956430     11  2069  52.063412   79  Male
# ...                         ...    ...   ...        ...  ...   ...
# 1544  ID00426637202313170790466     13  2712  66.594637   73  Male
# 1545  ID00426637202313170790466     19  2978  73.126412   73  Male
# 1546  ID00426637202313170790466     31  2908  71.407524   73  Male
# 1547  ID00426637202313170790466     43  2975  73.052745   73  Male
# 1548  ID00426637202313170790466     59  2774  68.117081   73  Male
#
#      SmokingStatus  WHERE
# 0        Ex-smoker  train
# 1        Ex-smoker  train
# 2        Ex-smoker  train
# 3        Ex-smoker  train
# 4        Ex-smoker  train
# ...            ...    ...
# 1544  Never smoked  train
# 1545  Never smoked  train
# 1546  Never smoked  train
# 1547  Never smoked  train
# 1548  Never smoked  train
#
# [1535 rows x 8 columns]

# %%
test
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus  \
# 0  ID00419637202311204720264      6  3020  70.186855   73  Male     Ex-smoker
# 1  ID00421637202311550012437     15  2739  82.045291   68  Male     Ex-smoker
# 2  ID00422637202311677017371      6  1930  76.672493   73  Male     Ex-smoker
# 3  ID00423637202312137826377     17  3294  79.258903   72  Male     Ex-smoker
# 4  ID00426637202313170790466      0  2925  71.824968   73  Male  Never smoked
#
#   WHERE
# 0   val
# 1   val
# 2   val
# 3   val
# 4   val

# %%
sub
# Out:
#                        Patient  Weeks  Confidence  \
# 0    ID00419637202311204720264    -12         100
# 1    ID00419637202311204720264    -11         100
# 2    ID00419637202311204720264    -10         100
# 3    ID00419637202311204720264     -9         100
# 4    ID00419637202311204720264     -8         100
# ..                         ...    ...         ...
# 725  ID00426637202313170790466    129         100
# 726  ID00426637202313170790466    130         100
# 727  ID00426637202313170790466    131         100
# 728  ID00426637202313170790466    132         100
# 729  ID00426637202313170790466    133         100
#
#                       Patient_Week   FVC    Percent  Age   Sex SmokingStatus  \
# 0    ID00419637202311204720264_-12  3020  70.186855   73  Male     Ex-smoker
# 1    ID00419637202311204720264_-11  3020  70.186855   73  Male     Ex-smoker
# 2    ID00419637202311204720264_-10  3020  70.186855   73  Male     Ex-smoker
# 3     ID00419637202311204720264_-9  3020  70.186855   73  Male     Ex-smoker
# 4     ID00419637202311204720264_-8  3020  70.186855   73  Male     Ex-smoker
# ..                             ...   ...        ...  ...   ...           ...
# 725  ID00426637202313170790466_129  2925  71.824968   73  Male  Never smoked
# 726  ID00426637202313170790466_130  2925  71.824968   73  Male  Never smoked
# 727  ID00426637202313170790466_131  2925  71.824968   73  Male  Never smoked
# 728  ID00426637202313170790466_132  2925  71.824968   73  Male  Never smoked
# 729  ID00426637202313170790466_133  2925  71.824968   73  Male  Never smoked
#
#     WHERE
# 0    test
# 1    test
# 2    test
# 3    test
# 4    test
# ..    ...
# 725  test
# 726  test
# 727  test
# 728  test
# 729  test
#
# [730 rows x 10 columns]

# %%
data = train.append([test, sub])
data
# Out:
#                        Patient  Weeks   FVC    Percent  Age   Sex  \
# 0    ID00007637202177411956430     -4  2315  58.253649   79  Male
# 1    ID00007637202177411956430      5  2214  55.712129   79  Male
# 2    ID00007637202177411956430      7  2061  51.862104   79  Male
# 3    ID00007637202177411956430      9  2144  53.950679   79  Male
# 4    ID00007637202177411956430     11  2069  52.063412   79  Male
# ..                         ...    ...   ...        ...  ...   ...
# 725  ID00426637202313170790466    129  2925  71.824968   73  Male
# 726  ID00426637202313170790466    130  2925  71.824968   73  Male
# 727  ID00426637202313170790466    131  2925  71.824968   73  Male
# 728  ID00426637202313170790466    132  2925  71.824968   73  Male
# 729  ID00426637202313170790466    133  2925  71.824968   73  Male
#
#     SmokingStatus  WHERE  Confidence                   Patient_Week
# 0       Ex-smoker  train         NaN                            NaN
# 1       Ex-smoker  train         NaN                            NaN
# 2       Ex-smoker  train         NaN                            NaN
# 3       Ex-smoker  train         NaN                            NaN
# 4       Ex-smoker  train         NaN                            NaN
# ..            ...    ...         ...                            ...
# 725  Never smoked   test       100.0  ID00426637202313170790466_129
# 726  Never smoked   test       100.0  ID00426637202313170790466_130
# 727  Never smoked   test       100.0  ID00426637202313170790466_131
# 728  Never smoked   test       100.0  ID00426637202313170790466_132
# 729  Never smoked   test       100.0  ID00426637202313170790466_133
#
# [2270 rows x 10 columns]

# %%
print('Training Data:',train.info(), end = "\n\n\n")

print('Testing Data:',test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1535 entries, 0 to 1548
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Patient        1535 non-null   object
#  1   Weeks          1535 non-null   int64
#  2   FVC            1535 non-null   int64
#  3   Percent        1535 non-null   float64
#  4   Age            1535 non-null   int64
#  5   Sex            1535 non-null   object
#  6   SmokingStatus  1535 non-null   object
#  7   WHERE          1535 non-null   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 107.9+ KB
# Training Data: None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Patient        5 non-null      object
#  1   Weeks          5 non-null      int64
#  2   FVC            5 non-null      int64
#  3   Percent        5 non-null      float64
#  4   Age            5 non-null      int64
#  5   Sex            5 non-null      object
#  6   SmokingStatus  5 non-null      object
#  7   WHERE          5 non-null      object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 448.0+ bytes
# Testing Data: None

# %%
data['min_week'] = data['Weeks']
data.loc[data.WHERE=='test','min_week'] = np.nan
data['min_week'] = data.groupby('Patient')['min_week'].transform('min')
data.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus  \
# 0  ID00007637202177411956430     -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430      5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430      7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430      9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430     11  2069  52.063412   79  Male     Ex-smoker
#
#    WHERE  Confidence Patient_Week  min_week
# 0  train         NaN          NaN      -4.0
# 1  train         NaN          NaN      -4.0
# 2  train         NaN          NaN      -4.0
# 3  train         NaN          NaN      -4.0
# 4  train         NaN          NaN      -4.0

# %%
base = data.loc[data.Weeks == data.min_week]
base
# Out:
#                        Patient  Weeks   FVC    Percent  Age   Sex  \
# 0    ID00007637202177411956430     -4  2315  58.253649   79  Male
# 9    ID00009637202177434476278      8  3660  85.282878   69  Male
# 18   ID00010637202177584971671      0  3523  94.724672   60  Male
# 27   ID00011637202177653955184      6  3326  85.987590   72  Male
# 36   ID00012637202177665765362     33  3418  93.726006   65  Male
# ..                         ...    ...   ...        ...  ...   ...
# 18   ID00419637202311204720264      6  3020  70.186855   73  Male
# 173  ID00421637202311550012437     15  2739  82.045291   68  Male
# 310  ID00422637202311677017371      6  1930  76.672493   73  Male
# 467  ID00423637202312137826377     17  3294  79.258903   72  Male
# 596  ID00426637202313170790466      0  2925  71.824968   73  Male
#
#     SmokingStatus  WHERE  Confidence                  Patient_Week  min_week
# 0       Ex-smoker  train         NaN                           NaN      -4.0
# 9       Ex-smoker  train         NaN                           NaN       8.0
# 18      Ex-smoker  train         NaN                           NaN       0.0
# 27      Ex-smoker  train         NaN                           NaN       6.0
# 36   Never smoked  train         NaN                           NaN      33.0
# ..            ...    ...         ...                           ...       ...
# 18      Ex-smoker   test       100.0   ID00419637202311204720264_6       6.0
# 173     Ex-smoker   test       100.0  ID00421637202311550012437_15      15.0
# 310     Ex-smoker   test       100.0   ID00422637202311677017371_6       6.0
# 467     Ex-smoker   test       100.0  ID00423637202312137826377_17      17.0
# 596  Never smoked   test       100.0   ID00426637202313170790466_0       0.0
#
# [186 rows x 11 columns]

# %%
base = data.loc[data.Weeks == data.min_week]
base = base[['Patient','FVC']].copy()
base.columns = ['Patient','min_FVC']
base['nb'] = 1
base['nb'] = base.groupby('Patient')['nb'].transform('cumsum')
base = base[base.nb==1]
base.drop('nb', axis=1, inplace=True)

# %%
data = data.merge(base, on='Patient', how='left')
data['base_week'] = data['Weeks'] - data['min_week']
del base

# %%
COLS = ['Sex','SmokingStatus']
FE = []
for col in COLS:
    for mod in data[col].unique():
        FE.append(mod)
        data[mod] = (data[col] == mod).astype(int)

# %%
data['age'] = (data['Age'] - data['Age'].min() ) / ( data['Age'].max() - data['Age'].min() )
data['BASE'] = (data['min_FVC'] - data['min_FVC'].min() ) / ( data['min_FVC'].max() - data['min_FVC'].min() )
data['week'] = (data['base_week'] - data['base_week'].min() ) / ( data['base_week'].max() - data['base_week'].min() )
data['percent'] = (data['Percent'] - data['Percent'].min() ) / ( data['Percent'].max() - data['Percent'].min() )
FE += ['age','percent','week','BASE']

# %%
train = data.loc[data.WHERE=='train']
test = data.loc[data.WHERE=='val']
sub = data.loc[data.WHERE=='test']
del data

# %%
train.shape, test.shape, sub.shape
# Out:
# ((1535, 22), (5, 22), (730, 22))

# %%
L.GRU
# Out:
# keras.layers.rnn.gru.GRU

# %%
C1, C2 = tf.constant(70, dtype='float32'), tf.constant(1000, dtype="float32")
#=============================#
def score(y_true, y_pred):
    tf.dtypes.cast(y_true, tf.float32)
    tf.dtypes.cast(y_pred, tf.float32)
    
    sigma = y_pred[:, 2] - y_pred[:, 0]
    fvc_pred = y_pred[:, 1]
    
    #sigma_clip = sigma + C1
    sigma_clip = tf.maximum(sigma, C1)
    # print(y_true[:, 0])
    # print(fvc_pred)
    y_true=float(y_true[:, 0])
    delta = tf.abs(y_true - fvc_pred)
    # print("hi")
    delta = tf.minimum(delta, C2)
    sq2 = tf.sqrt( tf.dtypes.cast(2, dtype=tf.float32) )
    metric = (delta / sigma_clip)*sq2 + tf.math.log(sigma_clip* sq2)
    return K.mean(metric)
#============================#
def qloss(y_true, y_pred):
    # Pinball loss for multiple quantiles
    qs = [0.2, 0.50, 0.8]
    q = tf.constant(np.array([qs]), dtype=tf.float32)
    y_true=float(y_true)
    e = y_true - y_pred
    # print("hi")
   
    v = tf.maximum(q*e, (q-1)*e)
    return K.mean(v)
#=============================#
def mloss(_lambda):
    def loss(y_true, y_pred):
        # print(y_pred)
        return _lambda * qloss(y_true, y_pred) + (1 - _lambda)*score(y_true, y_pred)
    return loss
#=================
def make_model():
    z = L.Input((9,), name="Patient")
    y = L.GRU(25, return_sequences=True)(tf.expand_dims(z, axis=-1))
    y = L.GRU(25, return_sequences=True)(y)
    y = L.Reshape([25*9])(y)
    x = L.Dense(100, activation="relu", name="d1")(y)
    x = L.Dense(100, activation="relu", name="d2")(x)
    x = L.Dense(100, activation="relu", name="d3")(x)
    p1 = L.Dense(3, activation="linear", name="p1")(x)
    p2 = L.Dense(3, activation="relu", name="p2")(x)
   
    preds = L.Lambda(lambda x: x[0] + tf.cumsum(x[1], axis=1), 
                     name="preds")([p1, p2])
   
    model = M.Model(z, preds, name="CNN")
    
    #model.compile(loss=qloss, optimizer="adam", metrics=[score])
    model.compile(loss=mloss(0.8), optimizer="adam", metrics=[score])
    
    return model

# %%
net = make_model()
print(net.summary())
print(net.count_params())
# Out:
# Model: "CNN"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Patient (InputLayer)           [(None, 9)]          0           []
#
#  tf.expand_dims (TFOpLambda)    (None, 9, 1)         0           ['Patient[0][0]']
#
#  gru (GRU)                      (None, 9, 25)        2100        ['tf.expand_dims[0][0]']
#
#  gru_1 (GRU)                    (None, 9, 25)        3900        ['gru[0][0]']
#
#  reshape (Reshape)              (None, 225)          0           ['gru_1[0][0]']
#
#  d1 (Dense)                     (None, 100)          22600       ['reshape[0][0]']
#
#  d2 (Dense)                     (None, 100)          10100       ['d1[0][0]']
#
#  d3 (Dense)                     (None, 100)          10100       ['d2[0][0]']
#
#  p1 (Dense)                     (None, 3)            303         ['d3[0][0]']
#
#  p2 (Dense)                     (None, 3)            303         ['d3[0][0]']
#
#  preds (Lambda)                 (None, 3)            0           ['p1[0][0]',
#                                                                   'p2[0][0]']
#
# ==================================================================================================
# Total params: 49,406
# Trainable params: 49,406
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 49406

# %%
y = train['FVC'].values
z = train[FE].values
ze = sub[FE].values
pe = np.zeros((ze.shape[0], 3))
pred = np.zeros((z.shape[0], 3))

# %%
NFOLD = 15
kf = KFold(n_splits=NFOLD)

# %%
# %%time
cnt = 0
i = 0
for tr_idx, val_idx in kf.split(z):
    cnt += 1
    print(f"FOLD {cnt}")
    net = make_model()
    net.fit(z[tr_idx], y[tr_idx], batch_size=BATCH_SIZE, epochs=800, 
            validation_data=(z[val_idx], y[val_idx]), verbose=0) #
    print("train", net.evaluate(z[tr_idx], y[tr_idx], verbose=0, batch_size=BATCH_SIZE))
    val_score = net.evaluate(z[val_idx], y[val_idx], verbose=0, batch_size=BATCH_SIZE)
    print("val", val_score)
    print("predict val...")
    print("predict test...")
    if val_score[1] < 6.8:
        pred[val_idx] = net.predict(z[val_idx], batch_size=BATCH_SIZE, verbose=0)
        pe = pe*i
        pe += net.predict(ze, batch_size=BATCH_SIZE, verbose=0)
        i+=1
        pe = pe/i
# Out:
# FOLD 1
# train [184.26119995117188, 8.006651878356934]
# val [134.74729919433594, 7.93880558013916]
# predict val...
# predict test...
# FOLD 2
# train [174.6935272216797, 7.953287124633789]
# val [193.84182739257812, 8.008917808532715]
# predict val...
# predict test...
# FOLD 3
# train [181.27444458007812, 8.014561653137207]
# val [200.23411560058594, 8.09223747253418]
# predict val...
# predict test...
# FOLD 4
# train [36.313865661621094, 6.414940357208252]
# val [47.56576156616211, 6.645596504211426]
# predict val...
# predict test...
# FOLD 5
# train [180.22352600097656, 7.977960109710693]
# val [125.27527618408203, 7.847334861755371]
# predict val...
# predict test...
# FOLD 6
# train [34.668392181396484, 6.375669956207275]
# val [35.5295524597168, 6.399587154388428]
# predict val...
# predict test...
# FOLD 7
# train [180.0581512451172, 7.993242263793945]
# val [186.4393310546875, 7.931587219238281]
# predict val...
# predict test...
# FOLD 8
# train [176.93727111816406, 7.998384475708008]
# val [234.34828186035156, 7.968912124633789]
# predict val...
# predict test...
# FOLD 9
# train [49.5731201171875, 6.762722492218018]
# val [58.46390151977539, 6.919013977050781]
# predict val...
# predict test...
# FOLD 10
# train [180.5578155517578, 7.993031024932861]
# val [184.7436981201172, 8.008833885192871]
# predict val...
# predict test...
# FOLD 11
# train [35.75893020629883, 6.414068698883057]
# val [35.1397705078125, 6.3946533203125]
# predict val...
# predict test...
# FOLD 12
# train [34.798011779785156, 6.364383697509766]
# val [44.74106216430664, 6.630177021026611]
# predict val...
# predict test...
# FOLD 13
# train [39.730838775634766, 6.535563945770264]
# val [58.84162139892578, 6.785793304443359]
# predict val...
# predict test...
# FOLD 14
# train [36.679107666015625, 6.4359283447265625]
# val [46.682003021240234, 6.6034836769104]
# predict val...
# predict test...
# FOLD 15
# train [163.52577209472656, 7.841337203979492]
# val [126.11638641357422, 7.700711250305176]
# predict val...
# predict test...
# CPU times: user 1h 7min 22s, sys: 1min 40s, total: 1h 9min 2s
# Wall time: 53min 4s

# %%
sigma_opt = mean_absolute_error(y, pred[:, 1])
unc = pred[:,2] - pred[:, 0]
sigma_mean = np.mean(unc)
print(sigma_opt, sigma_mean)
# Out:
# 993.9956650327006 149.68926417447068

# %%
idxs = np.random.randint(0, y.shape[0], 100)
plt.plot(y[idxs], label="ground truth")
plt.plot(pred[idxs, 0], label="q25")
plt.plot(pred[idxs, 1], label="q50")
plt.plot(pred[idxs, 2], label="q75")
plt.legend(loc="best")
plt.show()

# %%
print(unc.min(), unc.mean(), unc.max(), (unc>=0).mean())
# Out:
# 0.0 149.68926417447068 420.5107421875 1.0

# %%
plt.hist(unc)
plt.title("uncertainty in prediction")
plt.show()

# %%
sub.head()
# Out:
#                         Patient  Weeks   FVC    Percent  Age   Sex  \
# 1540  ID00419637202311204720264    -12  3020  70.186855   73  Male
# 1541  ID00419637202311204720264    -11  3020  70.186855   73  Male
# 1542  ID00419637202311204720264    -10  3020  70.186855   73  Male
# 1543  ID00419637202311204720264     -9  3020  70.186855   73  Male
# 1544  ID00419637202311204720264     -8  3020  70.186855   73  Male
#
#      SmokingStatus WHERE  Confidence                   Patient_Week  ...  \
# 1540     Ex-smoker  test       100.0  ID00419637202311204720264_-12  ...
# 1541     Ex-smoker  test       100.0  ID00419637202311204720264_-11  ...
# 1542     Ex-smoker  test       100.0  ID00419637202311204720264_-10  ...
# 1543     Ex-smoker  test       100.0   ID00419637202311204720264_-9  ...
# 1544     Ex-smoker  test       100.0   ID00419637202311204720264_-8  ...
#
#       base_week  Male  Female  Ex-smoker  Never smoked  Currently smokes  \
# 1540      -18.0     1       0          1             0                 0
# 1541      -17.0     1       0          1             0                 0
# 1542      -16.0     1       0          1             0                 0
# 1543      -15.0     1       0          1             0                 0
# 1544      -14.0     1       0          1             0                 0
#
#            age    BASE      week   percent
# 1540  0.615385  0.3724  0.067901  0.332421
# 1541  0.615385  0.3724  0.074074  0.332421
# 1542  0.615385  0.3724  0.080247  0.332421
# 1543  0.615385  0.3724  0.086420  0.332421
# 1544  0.615385  0.3724  0.092593  0.332421
#
# [5 rows x 22 columns]

# %%
sub['FVC1'] = 0.996  * pe[:, 1]
sub['Confidence1'] = pe[:, 2] - pe[:, 0]

# %%
subm = sub[['Patient_Week','FVC','Confidence','FVC1','Confidence1']].copy()

# %%
subm.loc[~subm.FVC1.isnull()].head(10)
# Out:
#                        Patient_Week   FVC  Confidence         FVC1  \
# 1540  ID00419637202311204720264_-12  3020       100.0  2872.805524
# 1541  ID00419637202311204720264_-11  3020       100.0  2869.795274
# 1542  ID00419637202311204720264_-10  3020       100.0  2866.676290
# 1543   ID00419637202311204720264_-9  3020       100.0  2863.450192
# 1544   ID00419637202311204720264_-8  3020       100.0  2860.119979
# 1545   ID00419637202311204720264_-7  3020       100.0  2856.687718
# 1546   ID00419637202311204720264_-6  3020       100.0  2853.156409
# 1547   ID00419637202311204720264_-5  3020       100.0  2849.569779
# 1548   ID00419637202311204720264_-4  3020       100.0  2845.955146
# 1549   ID00419637202311204720264_-3  3020       100.0  2842.277532
#
#       Confidence1
# 1540   224.938110
# 1541   225.244222
# 1542   225.556437
# 1543   225.874837
# 1544   226.199463
# 1545   226.529989
# 1546   226.866496
# 1547   227.204264
# 1548   227.540161
# 1549   227.878621

# %%
subm.loc[~subm.FVC1.isnull(),'FVC'] = subm.loc[~subm.FVC1.isnull(),'FVC1']
if sigma_mean<70:
    subm['Confidence'] = sigma_opt
else:
    subm.loc[~subm.FVC1.isnull(),'Confidence'] = subm.loc[~subm.FVC1.isnull(),'Confidence1']

# %%
subm.head()
# Out:
#                        Patient_Week          FVC  Confidence         FVC1  \
# 1540  ID00419637202311204720264_-12  2872.805524  224.938110  2872.805524
# 1541  ID00419637202311204720264_-11  2869.795274  225.244222  2869.795274
# 1542  ID00419637202311204720264_-10  2866.676290  225.556437  2866.676290
# 1543   ID00419637202311204720264_-9  2863.450192  225.874837  2863.450192
# 1544   ID00419637202311204720264_-8  2860.119979  226.199463  2860.119979
#
#       Confidence1
# 1540   224.938110
# 1541   225.244222
# 1542   225.556437
# 1543   225.874837
# 1544   226.199463

# %%
subm.describe().T
# Out:
#              count         mean         std          min          25%  \
# FVC          730.0  2670.386395  321.420072  2075.257328  2592.391767
# Confidence   730.0   235.328929   15.817256   195.469889   221.136281
# FVC1         730.0  2670.386395  321.420072  2075.257328  2592.391767
# Confidence1  730.0   235.328929   15.817256   195.469889   221.136281
#
#                      50%          75%          max
# FVC          2723.600602  2855.776795  3252.598042
# Confidence    237.501139   249.910451   257.889079
# FVC1         2723.600602  2855.776795  3252.598042
# Confidence1   237.501139   249.910451   257.889079

# %%
otest = pd.read_csv(path+'test.csv')
for i in range(len(otest)):
    subm.loc[subm['Patient_Week']==otest.Patient[i]+'_'+str(otest.Weeks[i]), 'FVC'] = otest.FVC[i]
    subm.loc[subm['Patient_Week']==otest.Patient[i]+'_'+str(otest.Weeks[i]), 'Confidence'] = 0.1

# %%
subm[["Patient_Week","FVC","Confidence"]].to_csv(path+"submission_MQR_GRU.csv", index=False)
